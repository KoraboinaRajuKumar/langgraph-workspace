# %%
print("OOPS")
# Out:
# OOPS

# %%
class cource:
    def cource_details(self,name,mentor):
        print(f"cource name:{name} and mentor name:{mentor}")

# %%
c=cource()
c.cource_details("AI","nihal")
# Out:
# cource name:AI and mentor name:nihal

# %%
class cource:
    def __init__(self,name,price):
        self.name=name
        self.price=price
    def print_details(self):
        print(f"cource name:{self.name} and price:{self.price}")

# %%
c=cource("AI",1000)
c.print_details()
# Out:
# cource name:AI and price:1000

# %%
c.price
# Out:
# 1000
