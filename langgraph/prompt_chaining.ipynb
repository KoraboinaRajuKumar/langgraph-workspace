# %%
from langchain_groq import ChatGroq
import os
from dotenv import load_dotenv

load_dotenv()

groq_api_key=os.getenv("GROQ_API_KEY")
# API key direct ga pass cheyyadam
llm = ChatGroq(
    model="llama-3.3-70b-versatile",
    api_key=groq_api_key
)

response = llm.invoke("What is the capital of Telangana?")
print(response.content)
# Out:
# The capital of Telangana is Hyderabad.

# %%
from langgraph.graph import StateGraph,START,END
from typing import TypedDict
class BlogState(TypedDict):
    title:str
    outline:str
    content:str
def create_outline(state:BlogState)->BlogState:
    title=state["title"]
    prompt=f"Create a detailed outline for a blog post with the title: {title}"
    outline=llm.invoke(prompt).content
    state['outline']=outline
    return state

def create_content(state:BlogState)->BlogState:
    title=state["title"]
    outline=state["outline"]
    prompt=f"Write a detailed blog post with the title: {title} and the following outline: {outline}"
    content=llm.invoke(prompt).content
    state['content']=content
    return state

# %%
graph=StateGraph(BlogState)

graph.add_node("Outline_Node", create_outline)
graph.add_node("Content_Node", create_content)

graph.add_edge(START, "Outline_Node")
graph.add_edge("Outline_Node", "Content_Node")
graph.add_edge("Outline_Node", END)

# %%
final_graph=graph.compile()

# %%
final_graph

# %%
final_ans=final_graph.invoke({"title": "The Future of AI in Healthcare"})

# %%
final_ans
# Out:
# {'title': 'The Future of AI in Healthcare',
# ...

# %%
#print(final_ans['outline'])
#print(final_ans['content'])
print(final_ans)
# Out:
# {'title': 'The Future of AI in Healthcare', 'outline': 'Here is a detailed outline for a blog post on "The Future of AI in Healthcare":\n\n**I. Introduction**\n\n* Brief overview of the current state of AI in healthcare\n* Importance of AI in improving healthcare outcomes and efficiency\n* Thesis statement: The future of AI in healthcare holds tremendous promise, with potential applications in diagnosis, treatment, and patient care.\n\n**II. Current Applications of AI in Healthcare**\n\n* Overview of current AI-powered healthcare technologies, such as:\n\t+ Electronic health records (EHRs)\n\t+ Clinical decision support systems (CDSSs)\n\t+ Medical imaging analysis\n\t+ Chatbots and virtual assistants\n* Examples of successful implementations of AI in healthcare, such as:\n\t+ IBM Watson Health\n\t+ Google DeepMind Health\n\t+ Microsoft Health Bot\n\n**III. Future Applications of AI in Healthcare**\n\n* Predictive analytics and personalized medicine:\n\t+ Using machine learning to an
# ...

# %% [markdown]
# {'title': 'The Future of AI in Healthcare', 'outline': 'Here is a detailed outline for a blog post on "The Future of AI in Healthcare":\n\n**I. Introduction**\n\n* Brief overview of the current state of AI in healthcare\n* Importance of AI in improving healthcare outcomes and efficiency\n* Thesis statement: The future of AI in healthcare holds tremendous promise, with potential applications in diagnosis, treatment, and patient care.\n\n**II. Current Applications of AI in Healthcare**\n\n* Overview of current AI-powered healthcare technologies, such as:\n\t+ Electronic health records (EHRs)\n\t+ Clinical decision support systems (CDSSs)\n\t+ Medical imaging analysis\n\t+ Chatbots and virtual assistants\n* Examples of successful implementations of AI in healthcare, such as:\n\t+ IBM Watson Health\n\t+ Google DeepMind Health\n\t+ Microsoft Health Bot\n\n**III. Future Applications of AI in Healthcare**\n\n* Predictive analytics and personalized medicine:\n\t+ Using machine learning to analyze genomic data and predict patient outcomes\n\t+ Personalized treatment plans based on individual patient characteristics\n* AI-assisted diagnosis and treatment:\n\t+ Computer vision for medical imaging analysis\n\t+ Natural language processing for clinical notes and medical literature analysis\n* Robotics and automation in healthcare:\n\t+ Surgical robots\n\t+ Autonomous hospital robots for patient care and transportation\n\n**IV. Emerging Trends in AI for Healthcare**\n\n* Explainable AI (XAI) and transparency in AI decision-making\n* Edge AI and real-time processing for healthcare applications\n* Quantum AI and its potential applications in healthcare\n* AI-powered mental health and wellness tools\n\n**V. Challenges and Limitations of AI in Healthcare**\n\n* Regulatory frameworks and compliance:\n\t+ HIPAA and data protection regulations\n\t+ FDA approval for medical devices and software\n* Data quality and availability:\n\t+ Electronic health record (EHR) data quality and standardization\n\t+ Access to large, diverse datasets for training AI models\n* Cybersecurity and patient data protection:\n\t+ Risks of data breaches and cyber attacks\n\t+ Strategies for securing AI-powered healthcare systems\n\n**VI. Future Directions and Opportunities**\n\n* Interoperability and integration of AI systems with existing healthcare infrastructure\n* Collaboration between healthcare professionals, AI researchers, and industry stakeholders\n* Investment in AI research and development for healthcare applications\n* Potential for AI to improve healthcare disparities and access to care\n\n**VII. Conclusion**\n\n* Recap of the current state and future potential of AI in healthcare\n* Call to action for healthcare professionals, researchers, and industry stakeholders to work together to realize the benefits of AI in healthcare\n* Final thoughts on the potential of AI to transform the healthcare industry and improve patient outcomes.\n\nThis outline provides a comprehensive framework for exploring the future of AI in healthcare, including current applications, emerging trends, challenges, and opportunities.', 'content': '**The Future of AI in Healthcare**\n\nThe integration of Artificial Intelligence (AI) in healthcare has been a rapidly evolving field, with the potential to revolutionize the way healthcare is delivered, making it more efficient, effective, and personalized. The current state of AI in healthcare is characterized by the increasing adoption of AI-powered technologies, such as electronic health records, clinical decision support systems, and medical imaging analysis. The importance of AI in improving healthcare outcomes and efficiency cannot be overstated, as it has the potential to enhance patient care, reduce costs, and improve the overall quality of healthcare. The future of AI in healthcare holds tremendous promise, with potential applications in diagnosis, treatment, and patient care.\n\n**Current Applications of AI in Healthcare**\n\nAI is already being used in various healthcare applications, including electronic health records (EHRs), clinical decision support systems (CDSSs), medical imaging analysis, and chatbots and virtual assistants. For example, IBM Watson Health is using AI to analyze medical images and provide diagnostic recommendations to doctors. Google DeepMind Health is using AI to analyze medical data and provide insights to healthcare professionals. Microsoft Health Bot is using AI to provide personalized health advice and support to patients. These are just a few examples of the many successful implementations of AI in healthcare.\n\nOther current applications of AI in healthcare include:\n\n* **Electronic Health Records (EHRs)**: AI-powered EHRs can help to improve the accuracy and efficiency of medical record-keeping, reducing the administrative burden on healthcare professionals.\n* **Clinical Decision Support Systems (CDSSs)**: AI-powered CDSSs can provide healthcare professionals with real-time clinical decision support, helping to improve the accuracy and effectiveness of diagnosis and treatment.\n* **Medical Imaging Analysis**: AI-powered medical imaging analysis can help to improve the accuracy and speed of medical image analysis, enabling healthcare professionals to make more informed decisions.\n* **Chatbots and Virtual Assistants**: AI-powered chatbots and virtual assistants can provide patients with personalized health advice and support, helping to improve patient engagement and outcomes.\n\n**Future Applications of AI in Healthcare**\n\nThe future of AI in healthcare is likely to be characterized by the increasing use of predictive analytics and personalized medicine. For example, machine learning can be used to analyze genomic data and predict patient outcomes, enabling healthcare professionals to develop personalized treatment plans based on individual patient characteristics. AI-assisted diagnosis and treatment is also likely to become more prevalent, with the use of computer vision for medical imaging analysis and natural language processing for clinical notes and medical literature analysis.\n\nOther future applications of AI in healthcare include:\n\n* **Predictive Analytics**: AI-powered predictive analytics can help to identify patients who are at risk of developing certain conditions, enabling healthcare professionals to take proactive steps to prevent or mitigate these conditions.\n* **Personalized Medicine**: AI-powered personalized medicine can help to tailor treatment plans to individual patients, taking into account their unique characteristics, medical history, and lifestyle.\n* **Robotics and Automation**: AI-powered robotics and automation can help to improve the efficiency and effectiveness of healthcare delivery, enabling healthcare professionals to focus on more complex and high-value tasks.\n\n**Emerging Trends in AI for Healthcare**\n\nThere are several emerging trends in AI for healthcare, including explainable AI (XAI) and transparency in AI decision-making, edge AI and real-time processing, quantum AI, and AI-powered mental health and wellness tools. Explainable AI (XAI) is a critical trend, as it enables healthcare professionals to understand the reasoning behind AI-driven decisions, improving trust and confidence in AI-powered systems. Edge AI and real-time processing are also important, as they enable AI-powered systems to process and analyze data in real-time, improving the speed and accuracy of decision-making.\n\nOther emerging trends in AI for healthcare include:\n\n* **Quantum AI**: Quantum AI has the potential to revolutionize the field of healthcare, enabling the analysis of complex medical data and the development of new treatments and therapies.\n* **AI-Powered Mental Health and Wellness Tools**: AI-powered mental health and wellness tools can provide patients with personalized support and guidance, helping to improve mental health outcomes and reduce the burden on healthcare systems.\n\n**Challenges and Limitations of AI in Healthcare**\n\nDespite the many potential benefits of AI in healthcare, there are several challenges and limitations that must be addressed. These include regulatory frameworks and compliance, data quality and availability, and cybersecurity and patient data protection. Regulatory frameworks and compliance are critical, as they help to ensure that AI-powered systems meet rigorous standards for safety and effectiveness. Data quality and availability are also essential, as high-quality data is required to train and validate AI models.\n\nOther challenges and limitations of AI in healthcare include:\n\n* **Data Standardization**: Data standardization is critical, as it enables the sharing and analysis of data across different healthcare systems and organizations.\n* **Cybersecurity**: Cybersecurity is essential, as it helps to protect patient data and prevent cyber attacks and data breaches.\n\n**Future Directions and Opportunities**\n\nThe future of AI in healthcare is likely to be characterized by the increasing integration of AI-powered systems with existing healthcare infrastructure. This will require collaboration between healthcare professionals, AI researchers, and industry stakeholders, as well as investment in AI research and development. There is also potential for AI to improve healthcare disparities and access to care, particularly in underserved communities.\n\nOther future directions and opportunities include:\n\n* **Interoperability**: Interoperability is critical, as it enables the sharing and analysis of data across different healthcare systems and organizations.\n* **Collaboration**: Collaboration between healthcare professionals, AI researchers, and industry stakeholders is essential, as it helps to ensure that AI-powered systems meet the needs of healthcare professionals and patients.\n* **Investment**: Investment in AI research and development is critical, as it helps to drive innovation and improvement in healthcare delivery.\n\n**Conclusion**\n\nIn conclusion, the future of AI in healthcare holds tremendous promise, with potential applications in diagnosis, treatment, and patient care. The current state of AI in healthcare is characterized by the increasing adoption of AI-powered technologies, and the future is likely to be characterized by the increasing use of predictive analytics and personalized medicine. However, there are several challenges and limitations that must be addressed, including regulatory frameworks and compliance, data quality and availability, and cybersecurity and patient data protection. By working together, healthcare professionals, AI researchers, and industry stakeholders can help to realize the benefits of AI in healthcare, improving patient outcomes and transforming the healthcare industry.'}
